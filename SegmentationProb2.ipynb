# %% [markdown]
# <B> Newyork Neighbourhood Lisiting

# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
import urllib.request

wiki = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = urllib.request.urlopen(wiki)

from bs4 import BeautifulSoup
soup = BeautifulSoup(page)
#print (soup.prettify())

# %%
right_table=soup.find('table', class_='wikitable sortable')
#right_table

# %%
#Generate lists
A=[]
B=[]
C=[]
for row in right_table.findAll("tr"):
    cells = row.findAll('td')
    if len(cells)==3: #Only extract table body not heading
        if cells[1].find(text=True).strip() != 'Not assigned':
            A.append(cells[0].find(text=True))
            B.append(cells[1].find(text=True))
            if cells[2].find(text=True).strip() == 'Not assigned':
                C.append(cells[1].find(text=True))
            else:
                C.append(cells[2].find(text=True))                                 
    
        
df=pd.DataFrame(A,columns=['Postal Code'])
df['Borough']=B
df['Neighbourhood']=C

df_consolidated = df.groupby(['Postal Code','Borough'])['Neighbourhood'].apply(','.join).reset_index()
df_consolidated
#df_consolidated.join(other=df,on='Borough',how='left')
#result = pd.merge(result,
                # df[['Postal Code','Borough']],
                # on='Borough',
                # how='left')
#result
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# 26          M3B        North York
# 27          M3C        North York
# 28          M3H        North York
# 29          M3J        North York
# ..          ...               ...
# 73          M6C              York
# 74          M6E              York
# 75          M6G  Downtown Toronto
# 76          M6H      West Toronto
# 77          M6J      West Toronto
# 78          M6K      West Toronto
# 79          M6L        North York
# 80          M6M              York
# 81          M6N              York
# 82          M6P      West Toronto
# 83          M6R      West Toronto
# 84          M6S      West Toronto
# 85          M7A      Queen's Park
# 86          M7R       Mississauga
# 87          M7Y      East Toronto
# 88          M8V         Etobicoke
# 89          M8W         Etobicoke
# 90          M8X         Etobicoke
# 91          M8Y         Etobicoke
# 92          M8Z         Etobicoke
# 93          M9A         Etobicoke
# 94          M9B         Etobicoke
# 95          M9C         Etobicoke
# 96          M9L        North York
# 97          M9M        North York
# 98          M9N              York
# 99          M9P         Etobicoke
# 100         M9R         Etobicoke
# 101         M9V         Etobicoke
# 102         M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                        Rouge,Malvern
# 1                 Highland Creek,Rouge Hill,Port Union
# 2                    Guildwood\n,Morningside,West Hill
# 3                                               Woburn
# 4                                          Cedarbrae\n
# 5                                  Scarborough Village
# 6          East Birchmount Park\n,Ionview,Kennedy Park
# 7                        Clairlea,Golden Mile,Oakridge
# 8      Cliffcrest,Cliffside,Scarborough Village West\n
# 9                         Birch Cliff,Cliffside West\n
# 10   Dorset Park,Scarborough Town Centre,Wexford He...
# 11                                    Maryvale,Wexford
# 12                                           Agincourt
# 13           Clarks Corners\n,Sullivan\n,Tam O'Shanter
# 14   Agincourt North,L'Amoreaux East\n,Milliken,Ste...
# 15                                   L'Amoreaux West\n
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                      Fairview\n,Henry Farm,Oriole\n
# 19                                     Bayview Village
# 20                           Silver Hills\n,York Mills
# 21                              Newtonbrook,Willowdale
# 22                                  Willowdale South\n
# 23                                   York Mills West\n
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                   Don Mills North\n
# 27                   Flemingdon Park,Don Mills South\n
# 28     Bathurst Manor,Downsview North\n,Wilson Heights
# 29                      Northwood Park,York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                               Caledonia-Fairbanks\n
# 75                                          Christie\n
# 76                       Dovercourt Village,Dufferin\n
# 77                             Little Portugal,Trinity
# 78        Brockton\n,Exhibition Place,Parkdale Village
# 79                Downsview,North Park\n,Upwood Park\n
# 80       Del Ray\n,Keelesdale,Mount Dennis,Silverthorn
# 81                    The Junction North\n,Runnymede\n
# 82                      High Park,The Junction South\n
# 83                               Parkdale,Roncesvalles
# 84                                   Runnymede,Swansea
# 85                                        Queen's Park
# 86             Canada Post Gateway Processing Centre\n
# 87   Business Reply Mail Processing Centre 969 East...
# 88      Humber Bay Shores\n,Mimico South\n,New Toronto
# 89                               Alderwood,Long Branch
# 90     The Kingsway,Montgomery Road\n,Old Mill North\n
# 91   Humber Bay,King's Mill Park\n,Kingsway Park So...
# 92   Kingsway Park South West\n,Mimico NW,The Queen...
# 93                                    Islington Avenue
# 94   Cloverdale\n,Islington,Martin Grove\n,Princess...
# 95   Bloordale Gardens\n,Eringate\n,Markland Wood,O...
# 96                                       Humber Summit
# 97                                     Emery,Humberlea
# 98                                              Weston
# 99                                         Westmount\n
# 100  Kingsview Village,Martin Grove Gardens\n,Richv...
# 101  Albion Gardens\n,Beaumond Heights,Humbergate\n...
# 102                                        Northwest\n
#
# [103 rows x 3 columns]

# %%
filename = "http://cocl.us/Geospatial_data/Geospatial_Coordinates.csv"
headers = ["Postal Code","Latitude","Longitude"]
df_LatLong = pd.read_csv(filename, names = headers)
df_LatLong.head()
# Out:
#    Postal Code    Latitude    Longitude
# 0  Postal Code    Latitude    Longitude
# 1          M1B  43.8066863  -79.1943534
# 2          M1C  43.7845351  -79.1604971
# 3          M1E  43.7635726  -79.1887115
# 4          M1G  43.7709921  -79.2169174

# %%
pd.merge(df_consolidated, df_LatLong, on='Postal Code')
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# 26          M3B        North York
# 27          M3C        North York
# 28          M3H        North York
# 29          M3J        North York
# ..          ...               ...
# 73          M6C              York
# 74          M6E              York
# 75          M6G  Downtown Toronto
# 76          M6H      West Toronto
# 77          M6J      West Toronto
# 78          M6K      West Toronto
# 79          M6L        North York
# 80          M6M              York
# 81          M6N              York
# 82          M6P      West Toronto
# 83          M6R      West Toronto
# 84          M6S      West Toronto
# 85          M7A      Queen's Park
# 86          M7R       Mississauga
# 87          M7Y      East Toronto
# 88          M8V         Etobicoke
# 89          M8W         Etobicoke
# 90          M8X         Etobicoke
# 91          M8Y         Etobicoke
# 92          M8Z         Etobicoke
# 93          M9A         Etobicoke
# 94          M9B         Etobicoke
# 95          M9C         Etobicoke
# 96          M9L        North York
# 97          M9M        North York
# 98          M9N              York
# 99          M9P         Etobicoke
# 100         M9R         Etobicoke
# 101         M9V         Etobicoke
# 102         M9W         Etobicoke
#
#                                          Neighbourhood    Latitude  \
# 0                                        Rouge,Malvern  43.8066863
# 1                 Highland Creek,Rouge Hill,Port Union  43.7845351
# 2                    Guildwood\n,Morningside,West Hill  43.7635726
# 3                                               Woburn  43.7709921
# 4                                          Cedarbrae\n   43.773136
# 5                                  Scarborough Village  43.7447342
# 6          East Birchmount Park\n,Ionview,Kennedy Park  43.7279292
# 7                        Clairlea,Golden Mile,Oakridge  43.7111117
# 8      Cliffcrest,Cliffside,Scarborough Village West\n   43.716316
# 9                         Birch Cliff,Cliffside West\n   43.692657
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.7574096
# 11                                    Maryvale,Wexford  43.7500715
# 12                                           Agincourt  43.7942003
# 13           Clarks Corners\n,Sullivan\n,Tam O'Shanter  43.7816375
# 14   Agincourt North,L'Amoreaux East\n,Milliken,Ste...  43.8152522
# 15                                   L'Amoreaux West\n  43.7995252
# 16                                         Upper Rouge  43.8361247
# 17                                   Hillcrest Village  43.8037622
# 18                      Fairview\n,Henry Farm,Oriole\n  43.7785175
# 19                                     Bayview Village  43.7869473
# 20                           Silver Hills\n,York Mills  43.7574902
# 21                              Newtonbrook,Willowdale   43.789053
# 22                                  Willowdale South\n  43.7701199
# 23                                   York Mills West\n  43.7527583
# 24                                     Willowdale West  43.7827364
# 25                                           Parkwoods  43.7532586
# 26                                   Don Mills North\n  43.7459058
# 27                   Flemingdon Park,Don Mills South\n  43.7258997
# 28     Bathurst Manor,Downsview North\n,Wilson Heights  43.7543283
# 29                      Northwood Park,York University  43.7679803
# ..                                                 ...         ...
# 73                                  Humewood-Cedarvale  43.6937813
# 74                               Caledonia-Fairbanks\n  43.6890256
# 75                                          Christie\n   43.669542
# 76                       Dovercourt Village,Dufferin\n  43.6690051
# 77                             Little Portugal,Trinity  43.6479267
# 78        Brockton\n,Exhibition Place,Parkdale Village  43.6368472
# 79                Downsview,North Park\n,Upwood Park\n  43.7137562
# 80       Del Ray\n,Keelesdale,Mount Dennis,Silverthorn  43.6911158
